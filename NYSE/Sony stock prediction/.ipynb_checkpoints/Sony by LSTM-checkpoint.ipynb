# %% [markdown]
# # Sony Stock Prediction - LSTM

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
dataset=pd.read_csv("SONY.csv")
display(dataset)
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      1973-02-21   0.000000   7.927273   7.672727   7.763636   5.828178
# 1      1973-02-22   0.000000   7.763636   7.581818   7.581818   5.691687
# 2      1973-02-23   0.000000   7.563636   7.400000   7.436364   5.582495
# 3      1973-02-26   0.000000   7.454545   7.181818   7.327273   5.500600
# 4      1973-02-27   0.000000   7.327273   7.163636   7.163636   5.377758
# ...           ...        ...        ...        ...        ...        ...
# 12418  2022-05-16  86.290001  87.160004  85.959999  86.360001  86.360001
# 12419  2022-05-17  87.470001  87.940002  86.809998  87.690002  87.690002
# 12420  2022-05-18  88.800003  89.230003  86.940002  87.070000  87.070000
# 12421  2022-05-19  88.099998  89.730003  87.870003  88.709999  88.709999
# 12422  2022-05-20  89.940002  90.500000  88.220001  89.940002  89.940002
#
#         Volume
# 0       378125
# 1       225500
# 2       173250
# 3       422125
# 4       250937
# ...        ...
# 12418   546100
# 12419   562300
# 12420  1066600
# 12421   778500
# 12422   806100
#
# [12423 rows x 7 columns]

# %%
dataset['Date']=pd.to_datetime(dataset['Date'])
dataset=dataset.sort_values('Date',ascending=True).reset_index(drop=True)
#dataset['Date']=dataset['Date'].astype(str)
display(dataset)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1973-02-21   0.000000   7.927273   7.672727   7.763636   5.828178
# 1     1973-02-22   0.000000   7.763636   7.581818   7.581818   5.691687
# 2     1973-02-23   0.000000   7.563636   7.400000   7.436364   5.582495
# 3     1973-02-26   0.000000   7.454545   7.181818   7.327273   5.500600
# 4     1973-02-27   0.000000   7.327273   7.163636   7.163636   5.377758
# ...          ...        ...        ...        ...        ...        ...
# 12418 2022-05-16  86.290001  87.160004  85.959999  86.360001  86.360001
# 12419 2022-05-17  87.470001  87.940002  86.809998  87.690002  87.690002
# 12420 2022-05-18  88.800003  89.230003  86.940002  87.070000  87.070000
# 12421 2022-05-19  88.099998  89.730003  87.870003  88.709999  88.709999
# 12422 2022-05-20  89.940002  90.500000  88.220001  89.940002  89.940002
#
#         Volume
# 0       378125
# 1       225500
# 2       173250
# 3       422125
# 4       250937
# ...        ...
# 12418   546100
# 12419   562300
# 12420  1066600
# 12421   778500
# 12422   806100
#
# [12423 rows x 7 columns]

# %%
trainset=dataset.iloc[-1000:-100,1:2].values #Open
testset=dataset.iloc[-100:,1:2].values #Open 
real_stock_price = testset.copy()

# %%
sc = MinMaxScaler(feature_range = (0,1))
training_scaled = sc.fit_transform(trainset)
print(training_scaled[0:5])
print(len(training_scaled))
# Out:
# [[0.0734148 ]
#  [0.08295522]
#  [0.09272834]
#  [0.09296105]
#  [0.08842354]]
# 900

# %%
x_train = []
y_train = []

# %%
for i in range(60,len(training_scaled)):
    x_train.append(training_scaled[i-60:i, 0])
    y_train.append(training_scaled[i,0])
x_train,y_train = np.array(x_train),np.array(y_train)
print(x_train.shape,y_train.shape)
# Out:
# (840, 60) (840,)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
print('(samples, time steps, features) =',x_train.shape)
# Out:
# (samples, time steps, features) = (840, 60, 1)

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50,return_sequences = True,input_shape = (x_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')
regressor.fit(x_train,y_train,epochs =10, batch_size = 32)
# Out:
# Epoch 1/10
# 27/27 [==============================] - 2s 30ms/step - loss: 0.0403
# Epoch 2/10
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0056
# Epoch 3/10
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0051
# Epoch 4/10
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0049
# Epoch 5/10
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0054
# Epoch 6/10
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0059
# Epoch 7/10
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0043
# Epoch 8/10
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0046
# Epoch 9/10
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0051
# Epoch 10/10
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0061

# %%
inputs = dataset.iloc[len(trainset)-len(testset)-60:,1].values
print(inputs.shape)
print(inputs[0:10])
# Out:
# (11683,)
# [3.681818 3.681818 3.681818 3.681818 3.681818 3.818182 3.909091 4.090909
#  4.147727 4.147727]

# %% [markdown]
# In the context of a LSTM model, this reshaping may be necessary if the input data has only one feature (i.e., one time series) and the LSTM model expects a 3D input shape of (n_samples, n_time_steps, n_features). In this case, since there is only one feature, the shape does not change.

# %%
inputs = inputs.reshape(-1,1)
print(inputs.shape)

#sc = MinMaxScaler(feature_range = (0,1))
inputs = sc.transform(inputs)
print(inputs.shape)
# Out:
# (11683, 1)
# (11683, 1)

# %%
x_test = []
for i in range(60,len(inputs)):
    x_test.append(inputs[i-60:i,0])
x_test = np.array(x_test)
print(x_test.shape)

x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print(x_test.shape)
# Out:
# (11623, 60)
# (11623, 60, 1)

# %%
predicted_price = regressor.predict(x_test)
# Out:
# 364/364 [==============================] - 4s 8ms/step

# %%
predicted_price = sc.inverse_transform(predicted_price)
print(predicted_price.shape)
# Out:
# (11623, 1)

# %%
plt.plot(real_stock_price[-100:],color = 'red', label = 'Real Price')
plt.plot(predicted_price[-100:], color = 'blue', label = 'Predicted Price')
plt.title('Sony Stock Price Prediction')
plt.xlabel('days')
plt.ylabel('Price')
plt.xlim(0,100)  
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.plot(dataset.iloc[-1000:-100,0],trainset,'-o',label='train actual')
#plt.plot(dataset.iloc[-1000:-100,0],train_pred,'--',label='Prophet')
plt.plot(dataset.iloc[-100:,0],real_stock_price[-100:],'-o',label='test actual')
plt.plot(dataset.iloc[-100:,0],predicted_price[-100:],'-o',label='test predicted')
plt.title('Sony Stock Price',size=24)
plt.xlabel('Date',size=16)
plt.ylabel('Price',size=16)
plt.legend()
plt.show()

# %%
inputs = np.array(trainset[-60:])
new_predicted_price=[]
for i in range(100):
    x = np.reshape(inputs, (1,60,1))
    pred = regressor.predict(x)
    inputs = np.append(inputs, pred)
    inputs = inputs[1:]
    new_predicted_price+=[pred.reshape(-1)]
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
new_predicted_price = sc.inverse_transform(np.array(new_predicted_price))
print(new_predicted_price.shape)
# Out:
# (100, 1)

# %%
plt.plot(real_stock_price,color = 'red', label = 'Real Price')
plt.plot(new_predicted_price, color = 'blue', label = 'New Predicted Price')
plt.title('sony Stock Price Prediction')
plt.xlabel('days')
plt.ylabel('Price')
plt.xlim(0,100)  
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.plot(dataset.iloc[-1000:-100,0],trainset,'-o',label='train actual')
#plt.plot(dataset.iloc[-1000:-100,0],train_pred,'--',label='Prophet')
plt.plot(dataset.iloc[-100:,0],real_stock_price[-100:],'-o',label='test actual')
plt.plot(dataset.iloc[-100:,0],new_predicted_price[-100:],'-o',label='test predicted')
plt.title('sony Stock Price',size=24)
plt.xlabel('Date',size=16)
plt.ylabel('Price',size=16)
plt.legend()
plt.show()
