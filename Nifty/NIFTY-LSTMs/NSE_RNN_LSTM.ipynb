# %%
import yfinance as yf
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow.keras as keras

# %%
# Get the data

start = dt.datetime(2010,1,1)
end = dt.datetime(2019,12,31)
stk_data = yf.download('NSE', start='2010-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# looking at the data
stk_data.shape
# Out:
# (1822, 6)

# %%
plt.figure(figsize=(14,14))
plt.plot(stk_data['Close'])
plt.title('Nifty Stock Value')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.show()

# %%
# cleaning up, subsettig
stk_data['Date'] = stk_data.index
nifty_df = pd.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close'])
nifty_df['Date'] = stk_data['Date']
nifty_df['Open'] = stk_data['Open']
nifty_df['High'] = stk_data['High']
nifty_df['Low'] = stk_data['Low']
nifty_df['Close'] = stk_data['Close']

# %%
# divide into train and test
# last 2 months as test
test = nifty_df[nifty_df['Date'] > pd.to_datetime('2019-1-1')]
nifty_df = nifty_df[nifty_df['Date'] <= pd.to_datetime('2019-1-1')]

# %%
print(test.shape)
print(nifty_df.shape)
# Out:
# (788, 5)
# (1034, 5)

# %% [markdown]
# ## Data Preprocessing

# %%
# selecting only the opening price
train_set = nifty_df.iloc[:, 1:2].values
nifty_df.iloc[:, 1:2].tail()
# Out:
#              Open
# Date
# 2018-12-24  13.75
# 2018-12-26  13.75
# 2018-12-27  14.10
# 2018-12-28  13.95
# 2018-12-31  14.55

# %%
# scaling
sc = MinMaxScaler(feature_range = (-1, 1))

training_set_scaled = sc.fit_transform(train_set)

# %%
# preparing data labels
# X - We use the previous 60 days data to create the training set
# Y - the 61st value serves as the Y value
# So standing at any point in time we are looking back 60 days to predict the 61st value

X_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
y_train = y_train.reshape(-1,1)

# %%
# creating test dataset

testdata = test.copy()
real_stock_price = testdata.iloc[:, 1:2].values
dataset_total = pd.concat((nifty_df['Open'], testdata['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(testdata) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []
for i in range(60, len(inputs)):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

y_test = sc.transform(real_stock_price)

# %% [markdown]
# # Simple RNN

# %%
import tensorflow as tf
# simple RNN 

model = keras.models.Sequential([
keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(), metrics = ['RootMeanSquaredError'])

history = model.fit(x=X_train, y=y_train, batch_size=32,epochs=15, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - RootMeanSquaredError: 1.2204 - loss: 1.4895 - val_RootMeanSquaredError: 1.1676 - val_loss: 1.3633
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.2139 - loss: 1.4741 - val_RootMeanSquaredError: 1.1586 - val_loss: 1.3423
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.1913 - loss: 1.4193 - val_RootMeanSquaredError: 1.1552 - val_loss: 1.3345
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.1562 - loss: 1.3370 - val_RootMeanSquaredError: 1.1547 - val_loss: 1.3334
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.1286 - loss: 1.2738 - val_RootMeanSquaredError: 1.1562 - val_loss: 1.3369
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.1390 - loss: 1.2987 - val_RootMeanSquaredError: 1.1585 - val_loss: 1.3422
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.0693 - loss: 1.1437 - val_RootMeanSquaredError: 1.1609 - val_loss: 1.3476
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 1.0372 - loss: 1.0763 - val_RootMeanSquaredError: 1.1630 - val_loss: 1.3526
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.9778 - loss: 0.9565 - val_RootMeanSquaredError: 1.1649 - val_loss: 1.3570
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.9311 - loss: 0.8679 - val_RootMeanSquaredError: 1.1672 - val_loss: 1.3625
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.8650 - loss: 0.7498 - val_RootMeanSquaredError: 1.1695 - val_loss: 1.3676
# Epoch 12/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.7723 - loss: 0.5974 - val_RootMeanSquaredError: 1.1711 - val_loss: 1.3714
# Epoch 13/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.7257 - loss: 0.5267 - val_RootMeanSquaredError: 1.1720 - val_loss: 1.3735
# Epoch 14/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.6967 - loss: 0.4855 - val_RootMeanSquaredError: 1.1717 - val_loss: 1.3728
# Epoch 15/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.6560 - loss: 0.4307 - val_RootMeanSquaredError: 1.1705 - val_loss: 1.3701

# %%
y_pred = sc.inverse_transform(model.predict(X_test))
loss = np.mean(abs(real_stock_price - y_pred))
loss
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16.273758902162466

# %%
plt.figure(figsize=(20,10))
plt.plot(real_stock_price, color = 'green', label = 'Nifty Stock Price')
plt.plot(y_pred, color = 'red', label = 'Predicted Nifty Stock Price')
plt.title('Nifty Stock Price Prediction')
plt.xlabel('Trading Day')
plt.ylabel('Nifty Stock Open Price')
#plt.ylim(bottom=0)

plt.legend()
plt.show()

# %% [markdown]
# # Deep RNN

# %%
# since multiple layers, we can run for more epochs 

model = keras.models.Sequential([
keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,
1]),
keras.layers.SimpleRNN(20, return_sequences=True),
keras.layers.SimpleRNN(20, return_sequences=True),
keras.layers.SimpleRNN(1)
])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(1e-4), metrics = ['RootMeanSquaredError'])

history = model.fit(x=X_train, y=y_train, batch_size=32,epochs=100,validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - RootMeanSquaredError: 1.2035 - loss: 1.4501 - val_RootMeanSquaredError: 0.8601 - val_loss: 0.7397
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.7116 - loss: 0.5098 - val_RootMeanSquaredError: 0.4581 - val_loss: 0.2098
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.4883 - loss: 0.2387 - val_RootMeanSquaredError: 0.2634 - val_loss: 0.0694
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.3204 - loss: 0.1033 - val_RootMeanSquaredError: 0.2585 - val_loss: 0.0668
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.2330 - loss: 0.0547 - val_RootMeanSquaredError: 0.1491 - val_loss: 0.0222
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1617 - loss: 0.0262 - val_RootMeanSquaredError: 0.1558 - val_loss: 0.0243
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1689 - loss: 0.0293 - val_RootMeanSquaredError: 0.1401 - val_loss: 0.0196
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1365 - loss: 0.0186 - val_RootMeanSquaredError: 0.1394 - val_loss: 0.0194
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1390 - loss: 0.0194 - val_RootMeanSquaredError: 0.1392 - val_loss: 0.0194
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1302 - loss: 0.0170 - val_RootMeanSquaredError: 0.1368 - val_loss: 0.0187
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1275 - loss: 0.0163 - val_RootMeanSquaredError: 0.1519 - val_loss: 0.0231
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1250 - loss: 0.0157 - val_RootMeanSquaredError: 0.1449 - val_loss: 0.0210
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - RootMeanSquaredError: 0.1266 - loss: 0.0161 - val_RootMeanSquaredError: 0.1453 - val_loss: 0.0211
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1124 - loss: 0.0127 - val_RootMeanSquaredError: 0.1345 - val_loss: 0.0181
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1160 - loss: 0.0136 - val_RootMeanSquaredError: 0.1278 - val_loss: 0.0163
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - RootMeanSquaredError: 0.1239 - loss: 0.0154 - val_RootMeanSquaredError: 0.1331 - val_loss: 0.0177
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1136 - loss: 0.0130 - val_RootMeanSquaredError: 0.1310 - val_loss: 0.0172
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1094 - loss: 0.0120 - val_RootMeanSquaredError: 0.1344 - val_loss: 0.0181
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1105 - loss: 0.0123 - val_RootMeanSquaredError: 0.1302 - val_loss: 0.0170
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.1186 - loss: 0.0142 - val_RootMeanSquaredError: 0.1229 - val_loss: 0.0151
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1279 - loss: 0.0166 - val_RootMeanSquaredError: 0.1309 - val_loss: 0.0171
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1182 - loss: 0.0140 - val_RootMeanSquaredError: 0.1242 - val_loss: 0.0154
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1310 - loss: 0.0182 - val_RootMeanSquaredError: 0.1287 - val_loss: 0.0166
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - RootMeanSquaredError: 0.1055 - loss: 0.0112 - val_RootMeanSquaredError: 0.1245 - val_loss: 0.0155
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1060 - loss: 0.0113 - val_RootMeanSquaredError: 0.1262 - val_loss: 0.0159
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1263 - loss: 0.0169 - val_RootMeanSquaredError: 0.1265 - val_loss: 0.0160
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1033 - loss: 0.0108 - val_RootMeanSquaredError: 0.1394 - val_loss: 0.0194
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1067 - loss: 0.0115 - val_RootMeanSquaredError: 0.1224 - val_loss: 0.0150
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1141 - loss: 0.0131 - val_RootMeanSquaredError: 0.1347 - val_loss: 0.0181
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1002 - loss: 0.0101 - val_RootMeanSquaredError: 0.1200 - val_loss: 0.0144
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0928 - loss: 0.0086 - val_RootMeanSquaredError: 0.1305 - val_loss: 0.0170
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0949 - loss: 0.0090 - val_RootMeanSquaredError: 0.1287 - val_loss: 0.0166
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0891 - loss: 0.0080 - val_RootMeanSquaredError: 0.1196 - val_loss: 0.0143
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1005 - loss: 0.0101 - val_RootMeanSquaredError: 0.1294 - val_loss: 0.0167
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0984 - loss: 0.0098 - val_RootMeanSquaredError: 0.1255 - val_loss: 0.0157
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0966 - loss: 0.0095 - val_RootMeanSquaredError: 0.1214 - val_loss: 0.0147
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1085 - loss: 0.0120 - val_RootMeanSquaredError: 0.1155 - val_loss: 0.0133
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1182 - loss: 0.0141 - val_RootMeanSquaredError: 0.1150 - val_loss: 0.0132
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0949 - loss: 0.0090 - val_RootMeanSquaredError: 0.1149 - val_loss: 0.0132
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1072 - loss: 0.0117 - val_RootMeanSquaredError: 0.1389 - val_loss: 0.0193
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0943 - loss: 0.0089 - val_RootMeanSquaredError: 0.1041 - val_loss: 0.0108
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0939 - loss: 0.0089 - val_RootMeanSquaredError: 0.1007 - val_loss: 0.0101
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0929 - loss: 0.0087 - val_RootMeanSquaredError: 0.1021 - val_loss: 0.0104
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.0927 - loss: 0.0086 - val_RootMeanSquaredError: 0.1027 - val_loss: 0.0105
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0891 - loss: 0.0080 - val_RootMeanSquaredError: 0.1151 - val_loss: 0.0133
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1010 - loss: 0.0104 - val_RootMeanSquaredError: 0.1156 - val_loss: 0.0134
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0987 - loss: 0.0098 - val_RootMeanSquaredError: 0.1149 - val_loss: 0.0132
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1029 - loss: 0.0107 - val_RootMeanSquaredError: 0.1106 - val_loss: 0.0122
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0973 - loss: 0.0096 - val_RootMeanSquaredError: 0.1040 - val_loss: 0.0108
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0860 - loss: 0.0074 - val_RootMeanSquaredError: 0.0956 - val_loss: 0.0091
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1196 - loss: 0.0156 - val_RootMeanSquaredError: 0.1032 - val_loss: 0.0107
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0885 - loss: 0.0078 - val_RootMeanSquaredError: 0.1042 - val_loss: 0.0108
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0894 - loss: 0.0081 - val_RootMeanSquaredError: 0.1062 - val_loss: 0.0113
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.0883 - loss: 0.0079 - val_RootMeanSquaredError: 0.1120 - val_loss: 0.0125
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0814 - loss: 0.0068 - val_RootMeanSquaredError: 0.1048 - val_loss: 0.0110
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.1023 - loss: 0.0107 - val_RootMeanSquaredError: 0.1163 - val_loss: 0.0135
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0890 - loss: 0.0080 - val_RootMeanSquaredError: 0.1009 - val_loss: 0.0102
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - RootMeanSquaredError: 0.0904 - loss: 0.0083 - val_RootMeanSquaredError: 0.1068 - val_loss: 0.0114
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0955 - loss: 0.0092 - val_RootMeanSquaredError: 0.1026 - val_loss: 0.0105
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0858 - loss: 0.0074 - val_RootMeanSquaredError: 0.0972 - val_loss: 0.0094
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0898 - loss: 0.0081 - val_RootMeanSquaredError: 0.1051 - val_loss: 0.0111
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0870 - loss: 0.0076 - val_RootMeanSquaredError: 0.1003 - val_loss: 0.0101
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.0777 - loss: 0.0061 - val_RootMeanSquaredError: 0.0979 - val_loss: 0.0096
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0986 - loss: 0.0098 - val_RootMeanSquaredError: 0.1110 - val_loss: 0.0123
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1118 - loss: 0.0131 - val_RootMeanSquaredError: 0.1029 - val_loss: 0.0106
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.1079 - loss: 0.0120 - val_RootMeanSquaredError: 0.1127 - val_loss: 0.0127
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0791 - loss: 0.0063 - val_RootMeanSquaredError: 0.1058 - val_loss: 0.0112
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.0885 - loss: 0.0079 - val_RootMeanSquaredError: 0.0961 - val_loss: 0.0092
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1106 - loss: 0.0128 - val_RootMeanSquaredError: 0.0953 - val_loss: 0.0091
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0809 - loss: 0.0067 - val_RootMeanSquaredError: 0.1158 - val_loss: 0.0134
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0998 - loss: 0.0101 - val_RootMeanSquaredError: 0.1096 - val_loss: 0.0120
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0776 - loss: 0.0061 - val_RootMeanSquaredError: 0.0970 - val_loss: 0.0094
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0840 - loss: 0.0071 - val_RootMeanSquaredError: 0.0987 - val_loss: 0.0097
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0802 - loss: 0.0065 - val_RootMeanSquaredError: 0.1041 - val_loss: 0.0108
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0896 - loss: 0.0081 - val_RootMeanSquaredError: 0.0960 - val_loss: 0.0092
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0810 - loss: 0.0067 - val_RootMeanSquaredError: 0.1108 - val_loss: 0.0123
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0773 - loss: 0.0060 - val_RootMeanSquaredError: 0.0934 - val_loss: 0.0087
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - RootMeanSquaredError: 0.0850 - loss: 0.0073 - val_RootMeanSquaredError: 0.0949 - val_loss: 0.0090
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0841 - loss: 0.0071 - val_RootMeanSquaredError: 0.1028 - val_loss: 0.0106
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0855 - loss: 0.0074 - val_RootMeanSquaredError: 0.1011 - val_loss: 0.0102
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0871 - loss: 0.0077 - val_RootMeanSquaredError: 0.0941 - val_loss: 0.0089
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1095 - loss: 0.0132 - val_RootMeanSquaredError: 0.0943 - val_loss: 0.0089
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0846 - loss: 0.0072 - val_RootMeanSquaredError: 0.0887 - val_loss: 0.0079
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - RootMeanSquaredError: 0.0766 - loss: 0.0059 - val_RootMeanSquaredError: 0.1008 - val_loss: 0.0102
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0854 - loss: 0.0073 - val_RootMeanSquaredError: 0.0975 - val_loss: 0.0095
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0845 - loss: 0.0072 - val_RootMeanSquaredError: 0.1187 - val_loss: 0.0141
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0857 - loss: 0.0074 - val_RootMeanSquaredError: 0.0881 - val_loss: 0.0078
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - RootMeanSquaredError: 0.0961 - loss: 0.0095 - val_RootMeanSquaredError: 0.0970 - val_loss: 0.0094
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0835 - loss: 0.0070 - val_RootMeanSquaredError: 0.0955 - val_loss: 0.0091
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0779 - loss: 0.0061 - val_RootMeanSquaredError: 0.0890 - val_loss: 0.0079
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0754 - loss: 0.0058 - val_RootMeanSquaredError: 0.0921 - val_loss: 0.0085
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - RootMeanSquaredError: 0.1075 - loss: 0.0128 - val_RootMeanSquaredError: 0.0927 - val_loss: 0.0086
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.0856 - loss: 0.0074 - val_RootMeanSquaredError: 0.0911 - val_loss: 0.0083
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0920 - loss: 0.0086 - val_RootMeanSquaredError: 0.0846 - val_loss: 0.0072
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.0786 - loss: 0.0063 - val_RootMeanSquaredError: 0.0859 - val_loss: 0.0074
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.1040 - loss: 0.0114 - val_RootMeanSquaredError: 0.0885 - val_loss: 0.0078
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0825 - loss: 0.0070 - val_RootMeanSquaredError: 0.0851 - val_loss: 0.0072
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - RootMeanSquaredError: 0.0806 - loss: 0.0066 - val_RootMeanSquaredError: 0.0974 - val_loss: 0.0095
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.0698 - loss: 0.0050 - val_RootMeanSquaredError: 0.0983 - val_loss: 0.0097
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.1102 - loss: 0.0136 - val_RootMeanSquaredError: 0.0911 - val_loss: 0.0083

# %%
y_pred = sc.inverse_transform(model.predict(X_test))
loss = np.mean(abs(real_stock_price - y_pred))

loss
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1.170238692748365

# %%
plt.figure(figsize=(20,10))
plt.plot(real_stock_price, color = 'green', label = 'Nifty Stock Price')
plt.plot(y_pred, color = 'red', label = 'Predicted Nifty Stock Price')
plt.title('Nifty Stock Price Prediction')
plt.xlabel('Trading Day')
plt.ylabel('Nifty Stock Open Price')
#plt.ylim(bottom=0)

plt.legend()
plt.show()

# %% [markdown]
# # LSTM Module

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0548
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0136
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0180
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0115
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0112
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0124
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0088
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0115
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0093
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0096
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0157
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0174
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0110
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0079
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0093
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0077
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0099
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0070
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0078
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0064
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0101
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0112
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0050
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0094
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0051
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0080
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0052
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0072
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0071
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0088
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0057
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0050
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0060
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0048
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0077
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0053
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0054
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0076
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0088
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0058
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0053
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0076
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0097
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0059
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0048
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0047
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0040
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0033
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0036
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0069
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0090
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0037
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0040
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0048
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0039
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0040
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0038
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0073
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0059
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0058
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0086
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0035
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0039
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0083
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0028
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0045
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0031
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0045
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0032
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0038
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0067
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0041
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0036
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0070
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0046
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0050
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0107
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0038
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0030
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0024
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0051
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0040
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0052
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0032
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0032
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0051
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0068
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0055
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0041
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0049
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0055
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0024
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0050
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0070
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0106
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0055
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0078
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0030
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0025

# %%
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
loss = np.mean(abs(real_stock_price - predicted_stock_price))
loss
# Out:
# 0.375607916546352

# %%
plt.figure(figsize=(20,10))
plt.plot(real_stock_price, color = 'green', label = 'Nifty Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Nifty Stock Price')
plt.title('Nifty Stock Price Prediction')
plt.xlabel('Trading Day')
plt.ylabel('Nifty Stock Open Price')
#plt.ylim(bottom=0)

plt.legend()
plt.show()
